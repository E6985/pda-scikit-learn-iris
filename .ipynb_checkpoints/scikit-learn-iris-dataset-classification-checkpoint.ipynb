# %% [markdown]
# < [GMIT Data Analytics](https://web.archive.org/web/20201029063153/https://www.gmit.ie/computer-science-and-applied-physics/higher-diploma-science-computing-data-analytics-ict) | [Table of Contents](https://github.com/E6985) | [README](https://github.com/E6985/pda-scikit-learn-iris/blob/main/README.md) >
#
# <img src="img/gmit.png" />
#
# ## scikit-learn-iris-dataset-classification
# ***

# %% [markdown]
# ###### Administration
# ***

# %% [markdown]
# - dark reader - unable to determine ticks [
# [...] CptanPanic, "How to handle labels when using dark theme with jupyterlabs?," github, October 2017.
# ]

# %%
from matplotlib.style.core import use as u

# %% [markdown]
# ###### Abstract
# ***

# %% [markdown]
# - package - scikit-learn - machine learning - python - loads of nice algorithms coded up already in scikit-learn - so you do not have to code them all up by yourself by hand - if you are interested in say k-nearest neighbours or other algorithms like that scikit-learn has them all coded up already and you just have to learn the concepts and the ideas involved - then you can quite quickly with maybe four or five commands code up a really serious machine learning algorithm on whatever datasets you are looking at - really powerful package [
# [...] I. McLoughlin, "Introduction to sklearn," GMIT, October 2018.
# ]

# %% [markdown]
# - other specialised packages - interested in neural networks - you can use scikit-learn but typically you would outsource something like that to its own specific packages that are really good for neural networks - keras - tensorflow - different libraries and packages like that [
# [...] I. McLoughlin, "Introduction to sklearn," GMIT, October 2018.
# ]

# %% [markdown]
# - if interested in those sorts of topical machine learning algorithms - scikit-learn might not be your first port of call - but at the same time even if you are using some other packages for machine learning - with your neural networks - you typically would use various helper methods in scikit-learn to clean up your dataset initially before you do any machine learning with it - so its a really powerful package - really good package to learn how to use - its pretty straightforward - pretty accessible [
# [...] I. McLoughlin, "Introduction to sklearn," GMIT, October 2018.
# ]

# %% [markdown]
# - [scikit-learn](https://web.archive.org/web/20201109090849/https://scikit-learn.org/stable/) - classification problems - regression - clustering problems which is quite like classification - dimensionality reduction which is when you have lots of different input variables or something like that and you want to just whittle them down to the most important ones - model selection allowing different ways of modelling datasets that you might have - and then theres a whole section on preprocessing which is kind of getting your dataset ready so that you can apply some techniques - might need to fill in some blanks or remove some outliers - or change variable types - or whatever - scikit-learn has all of these different things [
# [...] I. McLoughlin, "Introduction to sklearn," GMIT, October 2018.
# ]

# %% [markdown]
# - great documentation - [Getting Started](https://web.archive.org/web/20201020092727/https://scikit-learn.org/stable/getting_started.html) - theres a lot of terminology in there maybe that you will not be familiar with but the only way to get familiar with it is read down through the documentation - just accept that there will be certain parts that you will not know too much about - you might not understand everything that said there - the quickest way to learn all this stuff is to actually read stuff - even if you do not fully understand it - code snippets - can type into a Jupyter notebook or into python itself and see what they do and pick them apart - quickest way to learn how to do all these things - its just get outside your comfort zone a little bit and just kind of poke and prod around - within the tutorials - within the documentation - within the package - give things a whirl - you are never going to know everything about machine learning - theres too much out there and its an active area of research - so all you can do is sort of try and get familiar with the common bits and pieces - do not be afraid to hop in like you are learning how to drive a car - do not be afraid to hop into the car and give it a whirl even though you do not fully know everything about the car - scikit-learn - will use it to do a simple k-nearest neighbours classification problem [
# [...] I. McLoughlin, "Introduction to sklearn," GMIT, October 2018.
# ]

# %% [markdown]
# ###### Algorithm - k-nearest neighbors
# ***

# %% [markdown]
# - k-nearest neighbors - classification algorithm - iris dataset [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - package - pandas - get set up with - input variables - output variables [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - machine learning - Jupyter notebook - may not have a huge amount in it - not a lot of code - algorithms - should not be coding algorithms up by yourself from scratch because theres too many gotchas and too many mistakes you can make [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - scikit-learn - you are better off using an open source library that lots of people have looked at over a number of years - once you use one of those libraries however you can typically do something quite advanced with just a handful of statements in python [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - teaching these things - giving lectures - lectures tend to be quite short - its like - well here are the commands that you type - even though the algorithms are easy to run - its also easy to misuse - abuse - if you are using them to make predictions - its easy to get garbage predictions out of them - so what you really need to do is learn the theory behind the algorithms that you are using within the package so that the few commands that you do type - are typed correctly - are well informed - your idea to begin with in using the algorithm is sound - you understood the problem quite well [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - import - subpackage - neighbors - from package - scikit-learn - for dealing with nearest neighbors problem - rather than having to type - sklearn.neighbors - every single time to use a piece of its functionality - going to import it as alias - nei - short for neighbors - you will notice the American spelling of the package as well - probably written originally by Americans [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %%
# b_T_hird_P_arty-imports
import sklearn.neighbors as nei

# %% [markdown]
# - import - package - pandas - can just import pandas by itself but with scikit-learn you import the subpackages given that the package - scikit-learn - is a massive python package - broken down into subpackages - want to use something inside the package you have to import the specific subpackage that you are trying to use - cannot import the full package - scikit-learn - then access like it via dot notation - sklearn.neighbors [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ] - importing submodules - file - \_\_init\_\_.py - adds - \_\_all\_\_ - some package do - some do not - sklearn apparently does not [
# [...] poe123, "importing whole python module doesn't allow using submodules," [stackoverflow](https://web.archive.org/web/20201111093007/https://stackoverflow.com/questions/38143991/importing-whole-python-module-doesnt-allow-using-submodules), July 2016.
# ]

# %% [markdown]
# - the package is installed by default with anaconda - so thats good news - you do not have to go installing it - there are a couple of other subpackages within scikit-learn that you might be interested in importing - such as preprocessing or model selection [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %%
# b_T_hird_P_arty-imports
import pandas as pd

# %% [markdown]
# - load - iris dataset - pandas.read_csv - give it a url for the csv file - have got it hosted on one of my github repositories - url - if we have a look at it just to make sure its imported correctly - type in - df - DataFrame [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %%
# package pandas alias pd - subpackage io - module parsers - function read_csv - call
df=pd.read_csv("https://raw.githubusercontent.com/E6985/pda-pandas-iris/main/dataset/iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# - next step - visualise dataset - rerun the cell twice - sometimes Jupyter is a little bit finicky with seaborn - visualising dataset at this stage just to have a look at it to determine if it is in fact suitable for something like - k-nearest neighbors - got to build a case for using a given machine learning algorithm based on - observations - different summary statistics - plots [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %%
# b_T_hird_P_arty-imports
import seaborn as sns

# %%
# package matplotlib - subpackage style - module core - function use alias u - call
u("default")
# package seaborn alias sns - module axisgrid - function pairplot - call
sns.pairplot(df,hue="class");

# %% [markdown]
# - if we go back to the dataset - think its suitable for - k-nearest neighbors - want to use the subpackage to take the four variables at the start - sepal_length - sepal_width - petal_length - petal_width - use those four values to predict the class of iris flower given a set of values [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# - going to use the algorithm to build up - model - method - of using the values - sepal_length - sepal_width - petal_length - petal_width - to predict the class of a flower - so that if i come across a new iris flower - different to the - one-hundred and fifty known - can measure its four values - sepal_length - sepal_width - petal_length - petal_width - then i can go to my k-nearest neighbors algorithm and - say - got these four values - what class of iris do you think this is - hopefully the k-nearest neighbors algorithm will tell me with a relatively high accuracy the kind of class of iris - its likely to be based on the one-hundred and fifty observations thats its seen before [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - lets separate - DataFrame - df - into a set of - inputs - outputs - so that we can train up our k-nearest neighbors algorithm with a set of inputs for which we know the outputs for [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - inputs - name - nInputs - four variables - numeric - sepal_length - sepal_width - petal_length - petal_width - appropriate as inputs to the k-nearest neighbors algorithm because we can take various values of sepal_length away from other values of sepal_length and get something meaningful out of it - if one sepal_length is - 4.1 - another one is - 2.6 - can take one from the other and say that the difference is - 1.5 - that makes sense because the sepal_length is measured in centimetres - so i can take one length in centimetres away from another length in centimetres to find out what the difference is in centimetres between the two lengths - has a physical reality to it thats allowable with a variable like sepal_length - it would not be appropriate for a variable like class because class variables are categories [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - taking each of the four variables - sepal_length - sepal_width - petal_length - petal_width - create a new name - nInputs - assigned it to the DataFrame - df [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - out of the DataFrame - df - with square brackets going to select four of the five columns in the dataset telling the DataFrame to select - in square brackets - give it a list of values which happens to also be denoted by square brackets - the list is going to be the names of the columns that i want from the original DataFrame - with comma separation - will mean that name - nInputs - is now going to be like a subselection of the DataFrame - df - just four columns rather than five [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %%
nInput=df[["sepal_length","sepal_width","petal_length","petal_width"]]

# %% [markdown]
# - name- nInputs - just like - DataFrame - name - df - or data series - except it does not have the column - class [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %%
nInput
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# - outputs - name - nOutput - just the column - class - from the DataFrame - df [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %%
nOutput=df[["class"]]

# %% [markdown]
# - name- nOutput - just like - DataFrame - name - df - or data series - except it does not have the columns - sepal_length - sepal_width - petal_length - petal_width [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %%
nOutput
# Out:
#          class
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %% [markdown]
# - separated DataFrame - inputs - name - nInputs - outputs - name - nOutputs - thats as simple as it gets - have four variables interested in having as the inputs - sepal_length - sepal_width - petal_length - petal_width - decided that its reasonable to use these as inputs - they are the type of variables that will be suited in order to take one from another - are numeric values - the output variable - class - is a categorical variable which is appropriate for k-nearest neighbors [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - so the way you would know that is by reading up about - k-nearest neighbors - maybe reading the scikit-learn documentation about what k-nearest neighbors is about - figuring out that its appropriate to have these kinds of variables as input - sepal_length - sepal_width - petal_length - petal_width - the variable - class - as an output [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - idea - get k-nearest neighbors to build up a model - build up an idea of what the various inputs are - sepal_length - sepal width - petal length - petal width [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# - what is typically of setosa - what is typically of versicolor - what is typically of virginica - so that if i come along with a new flower with - sepal_length - sepal width - petal length - petal width - can ask the k-nearest neighbor setup - what class of iris do you think this is and it should tell me with a certain level of accuracy [
# [...] I. McLoughlin, "Loading inputs and outputs," GMIT, October 2018.
# ]

# %% [markdown]
# ***
# # END
